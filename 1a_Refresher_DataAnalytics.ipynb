# %% [markdown]
# <a href="https://colab.research.google.com/github/diseasemodeling/MIE_525_625/blob/main/1a_Refresher_DataAnalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Refresher to fundamental of data handling, and linear regression  ML

# %% [markdown]
# # **AI Policy**
# * **Use of AI for 'Review' sections**
#   * YOU CAN use it to understand concepts and sections of the code that are new to you
# * **Use of AI for sections 'Questions' and 'Programming exercises'**
#   * YOU CAN use to it verify your responses, or find more efficient ways of coding
#   * DO NOT use it to directly find answers. If you have done a good 'review' you should be able to answer these questions
# * **Discussions with classmates**
#   * YOU CAN 'discuss' with your classmates
#   * DO NOT 'copy' from classmates
#
# ___

# %% [markdown]
# ## Review Linear Regression
#
# ---
#
#
# * [Use this LINK to access Google Crash course to review the following](https://developers.google.com/machine-learning/crash-course/linear-regression)
#     * Overview of linear regression (the model architecture)
#     $\hat{y} = b+ w_1 x_1 + w_2 x_2 + w_3 x_3 + ... + w_N x_N$
#     * Loss: In model fitting, the objective function is to minimize the "Loss" between actual values ($y$) and predicted values ($\hat{y}$) using $n$ datapoints
#
#
#     $$ L(\mathbf{w}) = \sum_{i=1}^n (y_i - \mathbf{w}^\top \mathbf{x}_i)^2$$
#
#     * Gradient descent: which is the solution algorithm to solve for the coefficients $w$
#     * Hyperparameters
# NOte: NOt all basic machine learning courses teach gradient descent and hyperparmeter tuning. So it is ok if you are not familiar with these, but do review these so you are familiar with the terminologies.

# %% [markdown]
# ## Review below Data Processing topics - Follow the LINKS
#
# ---
# Data Handling
#
# Machine learning is all about learning from data. Data can be in various forms, and real data can be messy. Cleaning this data and converting it into a form that is useful is a signifcant part of any mahcine learning project. In interest of time, in this class I will not get into data processing and handling. You may have done this in other classes, if not is it is easy to learn on your own. Below are some resources.
#
# 1. [LINK: Vizualize the data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/numerical_data_stats.ipynb?utm_source=mlcc&utm_campaign=colab-external&utm_medium=referral&utm_content=numerical_data_stats#scrollTo=HYn5jBq2_Onh):
#    - It will take you to a .ipynb notebook by Google.
#    - It is a Google authored publicly accessible file on GoogleColab - you may need to login to Google (you can use your umass email for enterprise login or use a private account for these 'refresher' codes)
#     - Code cell maybe hidden - click on the 'show code'
#     - Run the code
#    - Review data sumamry statitics, check for outliers
# 2. [LINK: Modify bad data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/numerical_data_bad_values.ipynb?utm_source=mlcc&utm_campaign=colab-external&utm_medium=referral&utm_content=numerical_data_bad_values#scrollTo=-o-X5uIc7WJS)
#     - It will take you to a .ipynb notebook by Google.
#
# 3. [LINK to Google Crash Course - Categorical data preparation](https://developers.google.com/machine-learning/crash-course/categorical-data/one-hot-encoding)
#    - Introduction (What is encoding and why is it needed)
#    - One-hot encoding
#
#   3. [LINK to Google Crash Course - Data preparation](https://developers.google.com/machine-learning/crash-course/numerical-data/normalization): Review the below
#      - Imbalanced datasets
#      - Dividing the original dataset (test, train, validation splits)
#      - Data transformation
#      - cAtegorical data prepration: Data encoding, and one-hot encodingL It is under 'Working with Categorical Data' [LINK](https://developers.google.com/machine-learning/crash-course/categorical-data/one-hot-encoding)
#      - Normalization - it is under 'Working with Numerical Data' [use this LINK](https://developers.google.com/machine-learning/crash-course/numerical-data/normalization) (min-max scaling, z-score normalization, log transformation, clipping)
#      - Generalization and overfitting
#      - Model complexity and L2 regularization
#      - Interpreting loss curves

# %% [markdown]
# ## FYI- Statistical packages v Deep learning packages
# ---
#
# * Scikit Learn is the package typically used for statistical machine learning, such as linear regression. It has inbuilt regression functions
# * [Review -Sample linear regression  code in this scikit-learn LINK ](https://scikit-learn.org/1.5/auto_examples/linear_model/plot_ols.html)
#
# Deep Learning packages
# * Keras, Pytorch, Tensorflow are used for deep learning.
# * Most deep learning models use Object Oriented Programming (OOP). While Scikit learn are also built on OOP, we do not typically create our classes.

# %% [markdown]
# ## Overview of Computational Example using OOP
#
# ---
# Most deep learning models use Object Oriented Programming (OOP). Most introductory programming courses in Engineering (Python or MATLAB) do structured programming. So it is ok if you have not done OOP before. Below provides an intro. You can use AI to understand what each part of the code is doing. If you are not able to folllow all of it that is not a problem, but ATTEMPT is needed.
#
# This application uses the Tensorflow package: it is a good example for reviewing basics of OOP, gradient descent (including batching), that you reviewed in previous sections
#
#
# * Review this code from Tensorflow tutorials on this [LINK: Predicting fuel efficiency](https://www.tensorflow.org/guide/core/quickstart_core)
#
# Below are things to pay attention to:
#   * Observe use of object oriented programming
#     * 'Normalize' is a class;'norm_x' and norm_y' are objects of class
#     * def __init__(self, x)  #initializes variables at object creation
#       ```python
#       ``
#       class Normalize(tf.Module):
#         def __init__(self, x):
#           # Initialize the mean and standard deviation for normalization
#           self.mean = tf.math.reduce_mean(x, axis=0)
#           self.std = tf.math.reduce_std(x, axis=0)
#
#         def norm(self, x):
#           # Normalize the input
#           return (x - self.mean)/self.std
#
#         def unnorm(self, x):
#           # Unnormalize the input
#           return (x * self.std) + self.mean
#       ```
#     * 'norm_x' and 'norm_y' are objects of class; and can access functions defined within a class
#       ```python
#       norm_x = Normalize(x_train_ohe)
#       norm_y = Normalize(y_train)
#       x_train_norm, y_train_norm = norm_x.norm(x_train_ohe), norm_y.norm(y_train)
#       x_test_norm, y_test_norm = norm_x.norm(x_test_ohe), norm_y.norm(y_test)
#
#
#       ```
#
#    * Observe use of mini-batch training- batch size is typically $2^n$
#      * Observe use of batching and shuffling
#         ```python
#         batch_size = 64
#         train_dataset = tf.data.Dataset.from_tensor_slices((x_train_norm, y_train_norm))
#         train_dataset = train_dataset.shuffle(buffer_size=x_train.shape[0]).batch(batch_size)
#         test_dataset = tf.data.Dataset.from_tensor_slices((x_test_norm, y_test_norm))
#         test_dataset = test_dataset.shuffle(buffer_size=x_test.shape[0]).batch(batch_size)
#         ```
#
#       * Experiment as needed, e.g., run this code to understand 'from_tensor_slices'
#
#
#           ```python
#           #AI generated
#           import tensorflow as tf
#           import numpy as np
#
#           # Creating a dataset from a single NumPy array
#           data = np.array([1, 2, 3, 4, 5])
#           dataset_single = tf.data.Dataset.from_tensor_slices(data)
#
#           print("Dataset from single array:")
#           for element in dataset_single:
#               print(element.numpy())
#
#           # Creating a dataset from paired features and labels
#           features = np.array([[10, 20], [30, 40], [50, 60]])
#           labels = np.array([0, 1, 0])
#           dataset_paired = tf.data.Dataset.from_tensor_slices((features, labels))
#
#           print("\nDataset from paired features and labels:")
#           for feature_slice, label_slice in dataset_paired:
#               print(f"Features: {feature_slice.numpy()}, Label: {label_slice.numpy()}")
#           ```
#   * Observe steps of Stochastic Gradient Descent (SDG)(we typically use an inbuilt Class functions to do SDG; this code helps to understand what is happening internally in those function calls)
#       ```python
#         # Iterate through the training data
#         for x_batch, y_batch in train_dataset:
#           with tf.GradientTape() as tape:
#             y_pred_batch = lin_reg(x_batch)
#             batch_loss = mse_loss(y_pred_batch, y_batch)
#           # Update parameters with respect to the gradient calculations
#           grads = tape.gradient(batch_loss, lin_reg.variables)
#           for g,v in zip(grads, lin_reg.variables):
#             v.assign_sub(learning_rate * g)
#           # Keep track of batch-level training performance
#           batch_losses_train.append(batch_loss)
#       ```
#
# ___
